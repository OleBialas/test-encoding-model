# %%
import scipy
from matplotlib import pyplot as plt

# %%
data = scipy.io.loadmat('..\data\mSM63_09-Aug-2018.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Feb 14 14:48:05 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Vm': array([[-2.6082067e+00, -2.1025186e+00, -2.6073756e+00, ...,
#          -5.0601659e+00, -3.7209203e+00, -3.5005698e+00],
#         [-1.1021273e+00, -1.0403390e+00, -1.2041779e+00, ...,
#          -1.0248334e+00, -5.8752751e-01, -2.0042682e-01],
#         [ 3.5910770e-01,  4.6301001e-01,  3.1049168e-01, ...,
#          -6.7781404e-02, -1.3189957e-01,  1.6878019e-01],
#         ...,
#         [-1.1811773e-02, -2.8849288e-03,  1.5259777e-03, ...,
#          -5.5344652e-02, -5.2552507e-03,  1.7605517e-02],
#         [-2.5683234e-02, -2.2265440e-02, -2.2869714e-02, ...,
#           5.2779920e-02,  5.6305271e-02,  5.6847677e-02],
#         [ 3.3158615e-02,  3.1745490e-02,  2.9898563e-02, ...,
#           7.1811043e-03, -6.8250820e-03,  3.1271026e-02]],
#        shape=(200, 28200), dtype=float32),
# ...

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Vm', 'zeromeanVc', 'U', 'R', 'betas', 'lambdas', 'cMap', 'cMovie', 'regLabels', 'regIdx', 'rejIdx', 'regZeroFrames'])

# %%
data['betas'][0][0].shape
# Out:
# (2435, 200)

# %%
data['R'].shape
# Out:
# (28200, 2435)

# %%
plt.plot(data['R'][:1000, 100])

# %%
data['Vm'].shape
# Out:
# (200, 28200)

# %%
data['U'].shape
# Out:
# (540, 640, 200)

# %%
plt.imshow(data['U'][:, :, 199], aspect='auto', cmap='viridis')

# %%
data['zeromeanVc'].shape
plt.plot(data['zeromeanVc'][0, :1000])
plt.plot(data['Vm'][0, :1000])

# %%
plt.plot(data['Vm'][0:3, :1000].T)
